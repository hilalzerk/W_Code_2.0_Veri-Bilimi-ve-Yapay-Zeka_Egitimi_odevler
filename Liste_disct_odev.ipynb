# %% [markdown]
# ### Ödev 1
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
#
# 1. Aşağıdaki işlemleri indexing ve slicing kullanarak liste üzerinde uygulayın.
#
#    - "3" değerine ulaşmak için indexleme yapın.
#    - "Hi-Kod" değerine ulaşmak için indexleme yapın.
#    - 4.7 değerine ulaşmak için indexleme yapın.
#    - 9,"3",8.4,"Hi-Kod" değerlerine ulaşmak için slicing yapın.
#    - 8.4,"Hi-Kod","False",4.7 değerlerine ulaşmak için slicing yapın.

# %%
liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
liste[3]
# Out:
# '3'

# %%
liste[5]
# Out:
# 'Hi-Kod'

# %%
liste[-1]
# Out:
# 4.7

# %%
liste[2:6]
# Out:
# [9, '3', 8.4, 'Hi-Kod']

# %%
liste[4:]
# Out:
# [8.4, 'Hi-Kod', 'False', 4.7]

# %% [markdown]
# ### Ödev 2
#
# Verilen listede bulunan string veri tipindeki öğeleri yeni_liste isimli listeye eklenir.
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
yeni_liste= liste.copy()
print(yeni_liste)
# Out:
# ['Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7, 'Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7, 'Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7, 'Python', True, 9, '3', 8.4, 'Hi-Kod', 'False', 4.7]

# %% [markdown]
# ### Ödev 3
#
# Enumerate methodunu araştırın ve aşağıdaki örneği enumerate methodu ile yapın.

# %%
meyveler= ["elma", "armut", "muz", "çilek"]

for index in range(len(meyveler)):

    print("{}. indexte bulunan meyve: {}".format(index,meyveler[index]))
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: muz
# 3. indexte bulunan meyve: çilek

# %% [markdown]
# ## Sozluk

# %% [markdown]
# 1. Bir sözlük oluşturulur ve bu sözlükte öğrencilerin isimleri ve Matematik, Fizik, Kimya notları tutulur. Kullanıcıdan isim ve ders ismi(Matematik, Fizik, Kimya) istenir ve bu bilgilere göre çıktı verilir.

# %% [markdown]
# 2. Sözlük üzerinde değerleri değiştirme, yeni değer ekleme, kullanıcıya ulaşmak istediği bilgileri sorma gibi uygulamalar yapın.

# %%
notlar= {
    "Hilal" : {"Matematik" : 90 , "Fizik" : 85 , "Kimya" : 88},
    "Ahmet": {"Matematik": 75, "Fizik": 80, "Kimya": 70},
    "Zeynep": {"Matematik": 95, "Fizik": 92, "Kimya": 89}}    

isim = input("Öğrencinin ismini giriniz: ")
ders = input("Ders ismini giriniz (Matematik, Fizik, Kimya): ")

if isim in notlar:
    if ders in notlar[isim]:
        print(f"{isim} adlı öğrencinin {ders} notu: {notlar[isim][ders]}")
    else:
        print("Bu ders ismi bulunamadı.")
else:
    print("Bu isimde bir öğrenci bulunamadı.")
# Out:
# Öğrencinin ismini giriniz:  Hilal
# Ders ismini giriniz (Matematik, Fizik, Kimya):  Matematik
# Hilal adlı öğrencinin Matematik notu: 90

# %%
notlar["Hilal"]
# Out:
# {'Matematik': 90, 'Fizik': 85, 'Kimya': 88}

# %%
notlar["Beyza"]= {"Matematik" : 43 , "Fizik" : 57 , "Kimya" : 62}
print(notlar)
# Out:
# {'Hilal': {'Matematik': 90, 'Fizik': 85, 'Kimya': 88}, 'Ahmet': {'Matematik': 75, 'Fizik': 80, 'Kimya': 70}, 'Zeynep': {'Matematik': 95, 'Fizik': 92, 'Kimya': 89}, 'Beyza': {'Matematik': 43, 'Fizik': 57, 'Kimya': 62}}

# %%
notlar["Hilal"]["Matematik"]= 100
notlar["Hilal"]["Fizik"]= 100
notlar["Hilal"]["Kimya"]= 100
print(notlar)
# Out:
# {'Hilal': {'Matematik': 100, 'Fizik': 100, 'Kimya': 100}, 'Ahmet': {'Matematik': 75, 'Fizik': 80, 'Kimya': 70}, 'Zeynep': {'Matematik': 95, 'Fizik': 92, 'Kimya': 89}, 'Beyza': {'Matematik': 43, 'Fizik': 57, 'Kimya': 62}}

# %%
notlar["Ahmet"]["Matematik"]
# Out:
# 75
